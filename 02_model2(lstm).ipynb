# %%
import pandas as pd

df = pd.read_csv("text.csv", encoding="utf-8-sig")
# df.set_index(["时间", "股票代码"], inplace=True)
df.head(5)
# Out:
#    序号    股票代码   股票代码（两市）                                       文章标题  \
# 0   1   62689  000861.SZ                 海印股份称今珠多糖注射液专利尚未取得 不存在炒作股价
# 1   2  109423  002173.SZ                         创新医疗：信披违规 遭浙江证监局警示
# 2   3  185363  002639.SZ         雪人股份：控股股东将转让5%股份转让给福建省纾困一号股权投资合伙企业
# 3   4  131933  002322.SZ  理工环科：2021年半年度土壤修复营业收入为416万元 占营业收入比重为0.95%
# 4   5  396704  600375.SH                 华菱星马：吉利商用车集团收购公司股权案通过反垄断审查
#
#            时间                                               文章详情  情绪打分  情绪打分2  \
# 0   2019/6/22  　　6月22日凌晨，广东海印集团股份有限公司(<em>000861</em>，以下简称“海印...     1    1.0
# 1   2019/1/31   　　创新医疗(<em>002173</em>)1月31日晚公告，公司当日收到浙江证监局下达...     0    0.0
# 2  2019/12/19   　　雪人股份12月19日晚间公告，控股股东林汝捷与福建省纾困一号股权投资合伙企业于2019...     1    1.0
# 3  2021/11/11  　　每经AI快讯，有投资者在投资者互动平台提问：你好董秘，公司在土壤修复方面营业收入大致占多...     2    1.0
# 4    2020/9/1   　　9 月 1日，华菱星马发布公告称，2020年9月1日，公司收到吉利商用车集团转来的国家...     2    2.0
#
#    一致=0
# 0     0
# 1     0
# 2     0
# 3     1
# 4     0

# %%
import numpy as np
import re
import jieba
from gensim.models import Word2Vec

def preprocess(ar):
    for i, con in enumerate(ar):
        # 去掉标点或其他特殊符号
        con = re.sub("[\s+\.\!\/_,$%^*(+\"\']+|[+——！，。？、~@#￥%……&*（）]+：~", "", con)
        # jieba分词
        ar[i] = jieba.lcut(con, cut_all=False)
    return ar


def train_w2v_model(ar):
    model = Word2Vec(ar.flatten(), workers=4)
    return model

def word2vec(ar, model):
    para_avg_vec = []
    # print("training finished")
    # 对每一段
    for para in ar:
        sum_vec = np.zeros(100)
        # 对每一段中每一个词
        for word in para:
            try:
                # 试着从模型中取得word vector
                sum_vec += model.wv[word]
            except(KeyError):
                # 如果有未记录的特殊符号，就跳过
                continue
        # 对词向量求平均得到句子的向量表示
        para_avg_vec.append(sum_vec / len(para))
    return para_avg_vec

# %%
#word_2_vec_model = train_w2v_model(np.array(df["文章详情"]))
#word_2_vec_model.save('w2v_model')
word_2_vec_model = Word2Vec.load('w2v_model')
vec = word2vec(np.array(df["文章详情"]), word_2_vec_model)

# %%
df["vec"] = vec
print(df["文章详情"][0])
df["vec"][0]
# Out:
# 　　6月22日凌晨，广东海印集团股份有限公司(<em>000861</em>，以下简称“海印股份”)发布公告回复了日前深交所对该公司将参与“非洲猪瘟疫苗”投产一事下发的关注函。海印股份在公告中称，许启太团队研制的“今珠多糖注射液”属中药与天然药物制剂，并非疫苗。专利正在申请，尚未正式取得。　　此前...
# array([ 0.09405213,  0.00813369, -0.41396803,  0.12234212, -0.09115982,
#         0.27925893,  0.27831387,  0.04999109,  0.5007385 , -0.1825799 ,
#         0.66568163,  0.2137591 , -0.00985369,  0.27510145, -0.10254665,
#         0.00870984,  0.41533407,  0.06302615,  0.18787246,  0.0217877 ,
#         0.16150123, -0.4840593 ,  0.29276585,  0.10296157, -0.26743265,
#         0.01934119,  0.07534989, -0.03224325,  0.09248794, -0.09647534,
#        -0.17463405, -0.27878453,  0.21552915, -0.14428115,  0.19215189,
#        -0.34604797, -0.27785272, -0.1105668 , -0.21984906,  0.54569034,
#         0.22501971, -0.29924741,  0.10160562,  0.10169786, -0.13170739,
#        -0.30589651, -0.03016745, -0.17559056,  0.14371196,  0.30427059,
#         0.06986884,  0.1876137 , -0.12997348,  0.6415827 , -0.0997327 ,
#         0.18650104,  0.04861585, -0.31203435,  0.25392477, -0.15536632,
#         0.05697248, -0.35699273,  0.29066136,  0.35757723, -0.06944587,
#        -0.07997819, -0.11174433,  0.18157676, -0.10593209,  0.17651879,
#         0.05607658, -0.03172232,  0.00792035,  0.13568075,  0.13646246,
#        -0.28233189, -0.00795003,  0.04869654, -0.22083513,  0.1261482 ,
#        -0.3970463 ,  0.0855577 , -0.06267042, -0.39288811, -0.20534548,
#        -0.27164763,  0.08823763, -0.26808244,  0.06314395,  0.21518586,
#        -0.04082504, -0.06812534, -0.3011608 ,  0.22658279, -0.2362432 ,
#         0.0825765 , -0.12773085,  0.21822427, -0.45292019,  0.18557175])

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(df["vec"], df["情绪打分"], test_size=0.2, random_state=16) # 今日几号？16号咯

# %%
from tensorflow.keras import layers, losses
import tensorflow as tf

x_train, x_test = tf.convert_to_tensor(x_train.to_list()), tf.convert_to_tensor(x_test.to_list())
y_train, y_test = tf.convert_to_tensor(y_train), tf.convert_to_tensor(y_test)

# %%
def create_model(num_labels):
  model = tf.keras.Sequential([
      layers.Reshape((-1, 100, )),
      layers.LSTM(1024, activation="swish"),
      layers.Dense(128, activation="swish"),
      layers.Dense(num_labels)
  ])
  return model

model = create_model(num_labels=1)

model.compile(
    loss = "mae",
    optimizer='adam',
)

history = model.fit(
    x_train, y_train, epochs=100, validation_data=(x_test, y_test)
)
model.save('lstm')
# Out:
# Epoch 1/100
# 100/100 [==============================] - 19s 111ms/step - loss: 0.6739 - val_loss: 0.5460
# Epoch 2/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5800 - val_loss: 0.5301
# Epoch 3/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5674 - val_loss: 0.5343
# Epoch 4/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5636 - val_loss: 0.6611
# Epoch 5/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5664 - val_loss: 0.5275
# Epoch 6/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5616 - val_loss: 0.5224
# Epoch 7/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5574 - val_loss: 0.5276
# Epoch 8/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5546 - val_loss: 0.5262
# Epoch 9/100
# 100/100 [==============================] - 10s 101ms/step - loss: 0.5496 - val_loss: 0.5209
# Epoch 10/100
# 100/100 [==============================] - 10s 101ms/step - loss: 0.5499 - val_loss: 0.5138
# Epoch 11/100
# 100/100 [==============================] - 10s 101ms/step - loss: 0.5425 - val_loss: 0.5124
# Epoch 12/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5388 - val_loss: 0.5133
# Epoch 13/100
# 100/100 [==============================] - 10s 101ms/step - loss: 0.5403 - val_loss: 0.5148
# Epoch 14/100
# 100/100 [==============================] - 10s 99ms/step - loss: 0.5360 - val_loss: 0.5127
# Epoch 15/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5324 - val_loss: 0.5090
# Epoch 16/100
# 100/100 [==============================] - 10s 101ms/step - loss: 0.5322 - val_loss: 0.5115
# Epoch 17/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5282 - val_loss: 0.5088
# Epoch 18/100
# 100/100 [==============================] - 10s 101ms/step - loss: 0.5236 - val_loss: 0.5219
# Epoch 19/100
# 100/100 [==============================] - 10s 101ms/step - loss: 0.5219 - val_loss: 0.5086
# Epoch 20/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5174 - val_loss: 0.5090
# Epoch 21/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5217 - val_loss: 0.5089
# Epoch 22/100
# 100/100 [==============================] - 10s 99ms/step - loss: 0.5106 - val_loss: 0.5186
# Epoch 23/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5093 - val_loss: 0.5037
# Epoch 24/100
# 100/100 [==============================] - 10s 99ms/step - loss: 0.5088 - val_loss: 0.5169
# Epoch 25/100
# 100/100 [==============================] - 10s 101ms/step - loss: 0.5050 - val_loss: 0.5102
# Epoch 26/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5047 - val_loss: 0.5051
# Epoch 27/100
# 100/100 [==============================] - 10s 101ms/step - loss: 0.5046 - val_loss: 0.5090
# Epoch 28/100
# 100/100 [==============================] - 10s 99ms/step - loss: 0.5011 - val_loss: 0.5090
# Epoch 29/100
# 100/100 [==============================] - 8s 82ms/step - loss: 0.5001 - val_loss: 0.5005
# Epoch 30/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4955 - val_loss: 0.5067
# Epoch 31/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4977 - val_loss: 0.5148
# Epoch 32/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4898 - val_loss: 0.5109
# Epoch 33/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4895 - val_loss: 0.5025
# Epoch 34/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4896 - val_loss: 0.5100
# Epoch 35/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4829 - val_loss: 0.5007
# Epoch 36/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4882 - val_loss: 0.5002
# Epoch 37/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4815 - val_loss: 0.5134
# Epoch 38/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4746 - val_loss: 0.4967
# Epoch 39/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4782 - val_loss: 0.4979
# Epoch 40/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4780 - val_loss: 0.4956
# Epoch 41/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4728 - val_loss: 0.5124
# Epoch 42/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4718 - val_loss: 0.4963
# Epoch 43/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4733 - val_loss: 0.4951
# Epoch 44/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4724 - val_loss: 0.4975
# Epoch 45/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4751 - val_loss: 0.4927
# Epoch 46/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4685 - val_loss: 0.5002
# Epoch 47/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4700 - val_loss: 0.4939
# Epoch 48/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4613 - val_loss: 0.4953
# Epoch 49/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4636 - val_loss: 0.4982
# Epoch 50/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4645 - val_loss: 0.4954
# Epoch 51/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4587 - val_loss: 0.4957
# Epoch 52/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4561 - val_loss: 0.4977
# Epoch 53/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4562 - val_loss: 0.4920
# Epoch 54/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4560 - val_loss: 0.4972
# Epoch 55/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4519 - val_loss: 0.5203
# Epoch 56/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4504 - val_loss: 0.5005
# Epoch 57/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4451 - val_loss: 0.5022
# Epoch 58/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4454 - val_loss: 0.4994
# Epoch 59/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4497 - val_loss: 0.4981
# Epoch 60/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4448 - val_loss: 0.4998
# Epoch 61/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4461 - val_loss: 0.4957
# Epoch 62/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4416 - val_loss: 0.5274
# Epoch 63/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4496 - val_loss: 0.4928
# Epoch 64/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4423 - val_loss: 0.4991
# Epoch 65/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4374 - val_loss: 0.4890
# Epoch 66/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4402 - val_loss: 0.5137
# Epoch 67/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4377 - val_loss: 0.4914
# Epoch 68/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4321 - val_loss: 0.4935
# Epoch 69/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4354 - val_loss: 0.5017
# Epoch 70/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4302 - val_loss: 0.5104
# Epoch 71/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4401 - val_loss: 0.5013
# Epoch 72/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4322 - val_loss: 0.4973
# Epoch 73/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4218 - val_loss: 0.4988
# Epoch 74/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4262 - val_loss: 0.5031
# Epoch 75/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4245 - val_loss: 0.4976
# Epoch 76/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4177 - val_loss: 0.5067
# Epoch 77/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4233 - val_loss: 0.5031
# Epoch 78/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4184 - val_loss: 0.5000
# Epoch 79/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4171 - val_loss: 0.5138
# Epoch 80/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4185 - val_loss: 0.5118
# Epoch 81/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4189 - val_loss: 0.5151
# Epoch 82/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4202 - val_loss: 0.5089
# Epoch 83/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4167 - val_loss: 0.4978
# Epoch 84/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4226 - val_loss: 0.5077
# Epoch 85/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4114 - val_loss: 0.5006
# Epoch 86/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4118 - val_loss: 0.5075
# Epoch 87/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4110 - val_loss: 0.4992
# Epoch 88/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4097 - val_loss: 0.5053
# Epoch 89/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4048 - val_loss: 0.5028
# Epoch 90/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4078 - val_loss: 0.5013
# Epoch 91/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4052 - val_loss: 0.5039
# Epoch 92/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4073 - val_loss: 0.4982
# Epoch 93/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4036 - val_loss: 0.5028
# Epoch 94/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.4013 - val_loss: 0.5167
# Epoch 95/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.3975 - val_loss: 0.5056
# Epoch 96/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.3949 - val_loss: 0.5065
# Epoch 97/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4027 - val_loss: 0.5063
# Epoch 98/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.3959 - val_loss: 0.5199
# Epoch 99/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.3958 - val_loss: 0.4966
# Epoch 100/100
# 100/100 [==============================] - 7s 72ms/step - loss: 0.3933 - val_loss: 0.5016
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: lstm\assets
# INFO:tensorflow:Assets written to: lstm\assets

# %%
def accuracy(pred, y, num=[0, 2], num_labels=3):
    delta = num[1] - num[0]
    d = delta / num_labels
    acc = 0
    for i in range(len(pred)):
        c = 0
        if pred[i] <= num[0] + d:
            pred[i] = c
        elif pred[i] <= num[0] + 2*d:
            pred[i] = c + 1
        else:
            pred[i] = c + 2
    for i in range(len(pred)):
        if pred[i] == y[i]:
            acc += 1
    return acc / len(pred)

# %%
pred = model.predict(x_test)
accuracy(pred, y_test)
# Out:
# 25/25 [==============================] - 0s 8ms/step
# 0.605
